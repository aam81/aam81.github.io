# %%
import secrets
hash_value = secrets.token_hex(nbytes=16)[:10]
print(hash_value)
# Out:
# 993f276e05

# %%
import secrets
hash_value = secrets.token_hex(nbytes=16)[:10]
print(hash_value)
# Out:
# fb9c1173ae
